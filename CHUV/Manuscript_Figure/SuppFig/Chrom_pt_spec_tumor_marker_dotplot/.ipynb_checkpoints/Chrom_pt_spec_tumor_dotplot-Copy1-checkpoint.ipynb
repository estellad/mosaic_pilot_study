# %%
import scanpy as sc
import pandas as pd
import anndata as ad
import numpy as np
import os
from markers import *

# %%
disease = "breast"
disease = "lung"
disease = "dlbcl"

# %%
br_path = "/work/PRTNR/CHUV/DIR/rgottar1/spatial/Owkin_Pilot_Data/Chromium/Breast/breast_final_owkin_annot.h5ad"
lu_path = "/work/PRTNR/CHUV/DIR/rgottar1/spatial/Owkin_Pilot_Data/Chromium/Lung/lung_final_owkin_annot.h5ad"
dl_path = "/work/PRTNR/CHUV/DIR/rgottar1/spatial/Owkin_Pilot_Data/Chromium/DLBCL/DLBCL_final_owkin_annot.h5ad"

if disease == "breast":
    chrom = sc.read_h5ad(br_path)
    marker_genes = ["NAMPT", "FKBP5", "LTF", "STAC2", "ALOX15B", "ANKRD30A", "ALCAM", "FABP7", 
        "CYP4F8", "AZGP1", "CLU", "ALDH3B2", "FASN", "MGP", "ACSM1", "MUCL1", "APOD", 
        "GATA3", "EVL", "IER2", "NTN4", "ESR1", "SHROOM1", "KRT19", "MLPH", "RHOB"]
elif disease == "lung":
    chrom = sc.read_h5ad(lu_path)
    marker_genes = ["WFDC2", "F3", "TCIM", "HOPX", "AKR1C3", "PCSK2", "CPS1", "AKR1C2", "SFTPB", 
                    "GPRC5A", "PKHD1", "MYH14", "MSLN", "FXYD2", "ANXA4", "CD24", "MYO1D", "DDX52", "MUC1", 
                    "B2M", "FTH1", "CD74", "DCBLD2", "LAMB3", "CAV2", "TGFBI", "MDK", "COL17A1", "G0S2", "FAM3C", "ITGA3", 
                    "SERPINB1", "FURIN", "FXYD3", "AQP3", "DSP", "GSTP1", "TRIM29", "S100A9", "S100A2", "KRT17"]
else:
    chrom = sc.read_h5ad(dl_path)
    marker_genes = ["NME2", "FCRL1", "LMO2", "IGKC", "MT-CO3", "TMSB4X", "GRHPR",
              "MPEG1", "CD1C", "CD52", "LTB", "SMIM14", "TNFRSF13C", "CD79A",
              "CD22", "FCRL2", "FCRL5",                                    # D1 clus 2, 5, 13, 19:
              "MT-CYB", "NIBAN3", "SPIB", "MT-ATP6", "HIST1H1C", "IGHM",
              "MT-ND4", "TCL1A", "MT-ND4L", # "HIST1H1R",                    # D2 clus 0:
              "CD83", "SWAP70", "SEL1L3", "FCRL3", "ACTB", "IL4I1", "FAM3C",
              "ACTG2", "CD74", "MS4A1", "MT-CYB", "CNN2", "LRMP", "LCP1",  # D3 clus 1, 6, 26:
              "GGA2", "HELLS", "RASGRP2", "NKX6-3", "DTX1", "BCL7A", "MAT2A",
              "ARGLU1", "ALOX5", "AKNA", "ARHGEF1", "PNN", "TMC8",         # D4 clus 9&22:
              "TSPAN33", "SPATC1", "NFKB2", "BCL2L1", # "OGI", 
              "CCL17",
              "CD40", "DUSP2", "ITPKB", "CCL22",                           # D5 clus 17:
              "POU2F2", "CCDC88A", "LENG8", "KLHL6", "TNFRSF13B", "BCL2",
              "NFATC1", "MT-ND6", "NIBAN3", "FCRL2"]                        # D6 clus 12:

# %%
chrom.raw

# %%
chrom.obs.sample_id.value_counts()
# chrom.obs.patient.value_counts()
# Out:
# sample_id
# L3    17804
# L4    15592
# L2     1756
# L1      802
# Name: count, dtype: int64

# %%
chrom.raw = chrom

# %%
chrom.obs_names
# Out:
# Index(['L1_AAACAAGCAACAGGCTACTTTAGG-1', 'L1_AAACAAGCAGATAACTACTTTAGG-1',
#        'L1_AAACAAGCAGATTCGAACTTTAGG-1', 'L1_AAACCAGGTATGGGACACTTTAGG-1',
#        'L1_AAACGGGCAACAGGGAACTTTAGG-1', 'L1_AAACGGGCATGGCCGAACTTTAGG-1',
#        'L1_AAAGCCTAGCGCGAACACTTTAGG-1', 'L1_AAAGGCTTCCAGATAAACTTTAGG-1',
#        'L1_AAAGTAGCAGGATGCTACTTTAGG-1', 'L1_AAATCCTTCTGGCCATACTTTAGG-1',
#        ...
#        'L4_TTTGGCGGTTTCCTCAATGTTGAC-1', 'L4_TTTGTGAGTAGTTGTCATGTTGAC-1',
#        'L4_TTTGTGAGTCGAAGGTATGTTGAC-1', 'L4_TTTGTGAGTGAAGCACATGTTGAC-1',
#        'L4_TTTGTGAGTGAATCTCATGTTGAC-1', 'L4_TTTGTGAGTGTCCTTCATGTTGAC-1',
#        'L4_TTTGTGAGTGTGAGGTATGTTGAC-1', 'L4_TTTGTGAGTGTTTGTAATGTTGAC-1',
#        'L4_TTTGTGAGTTGGAGCGATGTTGAC-1', 'L4_TTTGTGAGTTTCGCCTATGTTGAC-1'],
#       dtype='object', length=35954)

# %%
# count_value = chrom.X[chrom.obs_names.get_loc("L1_AAACAAGCAACAGGCTACTTTAGG-1"), chrom.var_names.get_loc("A2M")]
# count_value

# %%
sc.pp.normalize_total(chrom, target_sum=1e4)
sc.pp.log1p(chrom)

# %%
genes_in_data = chrom.var_names
genes_not_found = [gene for gene in marker_genes if gene not in genes_in_data]
genes_not_found
# Out:
# []

# %%
chrom.obs.Level2.value_counts()
# Out:
# Level2
# T_NK            11398
# Myeloid          7988
# B                7598
# Fibro_muscle     3916
# Tu_L4            1407
# Vessel            855
# Epithelia         648
# Tu_L2             637
# Tu_L3             578
# Mast_cell         439
# Tu_L1             306
# Granulocyte       184
# Name: count, dtype: int64

# %%
chrom_subset = chrom[chrom.obs['Level2'].isin(["Tu_L1", "Tu_L2", "Tu_L3", "Tu_L4"]), :]
chrom_subset = chrom[chrom.obs['Level2'].isin(["Tu_L1", "Tu_L2", "Tu_L3", "Tu_L4"]), :]
chrom_subset = chrom[chrom.obs['Level2'].isin(["Tu_L1", "Tu_L2", "Tu_L3", "Tu_L4"]), :]

# %%
chrom_subset
# Out:
# View of AnnData object with n_obs × n_vars = 2928 × 18082
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'sample_id', 'percent_mt', 'percent_ribo', 'percent_hb', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.8', 'seurat_clusters', 'SCT_snn_res.0.5', 'SCT_snn_res.0.4', 'SCT_snn_res.2', 'patient', 'nCount_SoupX', 'nFeature_SoupX', 'Harmonised_Level4', 'Level3', 'Level2', 'Level1', 'ident'
#     uns: 'X_name', 'log1p'
#     obsm: 'PCA', 'UMAP'
#     layers: 'logcounts'

# %%
fig = sc.pl.dotplot(chrom_subset, marker_genes[::-1], 
              # groupby = "patient", 
              # groupby = "sample_id",
              groupby = "Level2",
              standard_scale = "var", 
              log = False, 
              swap_axes = True,
              figsize=(5, 12),
              dot_min = 0, 
              return_fig = True)

fig.savefig("/work/PRTNR/CHUV/DIR/rgottar1/spatial/Owkin_Pilot_Results/Manuscript_Figures_Final/SuppFig/Chrom_Pt_Spec_Tumor_DotPlot/lung_dotplot.pdf", format='pdf')
# Out:
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/ydong/Mamba/envs/cellcharter-env/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:168: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   obs_bool.groupby(level=0).sum() / obs_bool.groupby(level=0).count()
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/ydong/Mamba/envs/cellcharter-env/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:178: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dot_color_df = self.obs_tidy.groupby(level=0).mean()
# /work/PRTNR/CHUV/DIR/rgottar1/spatial/env/ydong/Mamba/envs/cellcharter-env/lib/python3.10/site-packages/scanpy/plotting/_dotplot.py:747: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)

# %%
cdm_out = calculate_markers(chrom, group_key = "patient", exclude = None, cnt_cut=0, tot_cnt_cut=0)

# %%
cdm_out
# Out:
# {'cnt': {'L1': array([  0., 122.,   0., ..., 108., 186., 155.]),
#   'L2': array([  0., 148.,   1., ..., 179., 487., 233.]),
#   'L3': array([5.000e+00, 4.291e+03, 2.000e+00, ..., 1.950e+03, 7.525e+03,
#          3.460e+03]),
#   'L4': array([   0., 1962.,  276., ..., 1145., 3991., 2316.])},
#  'drop': {'L1': array([0.        , 0.1521197 , 0.        , ..., 0.13466334, 0.2319202 ,
#          0.19326683]),
#   'L2': array([0.        , 0.08428246, 0.00056948, ..., 0.10193622, 0.27733485,
#          0.13268793]),
#   'L3': array([2.80835767e-04, 2.41013255e-01, 1.12334307e-04, ...,
#          1.09525949e-01, 4.22657830e-01, 1.94338351e-01]),
#   'L4': array([0.        , 0.12583376, 0.01770139, ..., 0.07343509, 0.2559646 ,
#          0.14853771])},
#  'mean': {'L1': array([0.        , 0.44622098, 0.        , ..., 0.1705495 , 0.4408727 ,
#          0.28874363]),
#   'L2': array([0.00000000e+00, 2.11904440e-01, 3.27407168e-04, ...,
#          1.44112501e-01, 5.78728381e-01, 2.06697801e-01]),
#   'L3': array([2.78863658e-04, 4.89007544e-01, 3.75901310e-05, ...,
#          1.51758200e-01, 9.08033150e-01, 3.23032621e-01]),
#   'L4': array([0.        , 0.29829652, 0.02708455, ..., 0.12022258, 0.55804274,
#          0.2736517 ])}}

# %%
draw_marker_blob(chrom, cdm_out=cdm_out, genes=marker_genes[::-1],
                min_drop_ratio=.0)
